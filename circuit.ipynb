# %% [markdown]
# # For calculations

# %% [markdown]
# # Circuit for voltage sampling
#
# ![WhatsApp Image 2022-03-23 at 7.05.03 AM.jpeg](data:image/jpeg;base64,...)
#
# ![WhatsApp Image 2022-03-23 at 7.19.56 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![](https://drive.google.com/file/d/1um9C-2ZCAL_iOF7xNP7DTwQ9uP118Zjo/view?usp=sharing)
